# %% [markdown]
# # Data Understanding
#
# remove later:
#
# order of sorting
#
# 1. rental analysis
# 2. geo map
# 3. nea list
# 4. population
# 5. mrt map

# %%
# import required libraries
import pandas as pd
from pathlib import Path
import geopandas as gpd

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Data Preparation
