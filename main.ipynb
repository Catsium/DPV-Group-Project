# %% [markdown]
# # Data Understanding
#
# remove later:
#
# order of sorting
#
# 1. rental analysis
# 2. geo map
# 3. nea list
# 4. population
# 5. mrt map

# %%
# import required libraries

import pandas as pd
from pathlib import Path
#import geopandas as gpd

# %%
# import the datasets

dataset_path = Path('Datasets')

# dataset paths

rental_dataset_path = dataset_path / 'CommercialRetailRentalAnalysis20260629170349.csv'
geo_dataset_path = dataset_path / 'MasterPlan2019PlanningAreaBoundaryNoSea.geojson'
nea_license_dataset_path = dataset_path / 'ListofNEALicensedEatingEstablishments.csv'
population_dataset_path = dataset_path / 'ResidentPopulationbyPlanningAreaSubzoneofResidenceandTypeofDwellingCensusofPopulation2020.csv'
mrt_traffic_dataset_path = dataset_path / 'origin_destination_train_202605.csv'



# datasets

rental_dataset = pd.read_csv(rental_dataset_path)
#geo_dataset = pd.read_csv(geo_dataset_path)
nea_license_dataset = pd.read_csv(nea_license_dataset_path)
population_dataset = pd.read_csv(population_dataset_path)
mrt_traffic_dataset = pd.read_csv(mrt_traffic_dataset_path)

# %% [markdown]
# ## Commerical Retail Rental Dataset

# %%
rental_dataset.head()
# Out:
#    Postal District Floor Level Floor Area (SQM)  25th Percentile ($ PSM)  \
# 0                1  B1 & Below       30 & Below                    69.89
# 1                1  B1 & Below        >30 - 100                    65.45
# 2                1  B1 & Below       >100 - 300                    50.33
# 3                1     Level 1       30 & Below                    87.36
# 4                1     Level 1        >30 - 100                    75.26
#
#   Median ($PSM) 75th Percentile ($PSM) Reference Period
# 0         70.20                 112.70           2021Q1
# 1         87.61                  98.41           2021Q1
# 2         57.70                  87.20           2021Q1
# 3        123.94                 222.00           2021Q1
# 4        109.37                 147.04           2021Q1

# %% [markdown]
# ## Geo Dataset

# %% [markdown]
# ## NEA Licensed Eating Establishments Dataset

# %%
nea_license_dataset.head()
# Out:
#                        licensee_name licence_number  \
# 0  REPUBLIC HOTELS & RESORTS LIMITED     W99288X000
# 1  REPUBLIC HOTELS & RESORTS LIMITED     W99281K000
# 2                  M.K. RAMA PTE LTD     W96344L000
# 3      GRAND PARK PROPERTY PTE. LTD.     W96230L000
# 4           MILLENIA PRIVATE LIMITED     W96214L000
#
#                                     premises_address grade demerit_points  \
# 0  392 HAVELOCK ROAD (FISH/MEAT) GRAND COPTHORNE ...     A             na
# 1  392 HAVELOCK ROAD (BANQUET KITCHEN) GRAND COPT...     A             na
# 2                    37 NORRIS ROAD SINGAPORE 208279     A             na
# 3  10 COLEMAN STREET (2ND STOREY) GRAND PARK CITY...     A             na
# 4  2 TEMASEK BOULEVARD #B1-00 CONRAD CENTENNIAL S...     A             na
#
#   suspension_start_date suspension_end_date
# 0                    na                  na
# 1                    na                  na
# 2                    na                  na
# ...

# %% [markdown]
# ## Population by Planning Area Subzone Dataset

# %%
population_dataset.head()
# Out:
#                    Number    Total HDBDwellings_Total  \
# 0                   Total  4044210            3152410
# 1      Ang Mo Kio - Total   162280             131020
# 2  Ang Mo Kio Town Centre     4810               2830
# 3               Cheng San    28070              27970
# 4              Chong Boon    26500              26000
#
#   HDBDwellings_1_and2_RoomFlats1 HDBDwellings_3_RoomFlats  \
# 0                         177360                   575200
# 1                          10720                    55910
# 2                              -                      400
# 3                            970                    13290
# 4                           1470                    12180
#
#   HDBDwellings_4_RoomFlats HDBDwellings_5_RoomandExecutiveFlats  \
# 0                  1338370                              1061480
# 1                    43030                                21370
# 2                      630                                 1800
# ...

# %% [markdown]
# ## MRT Traffic by station code dataset

# %%
mrt_traffic_dataset.head()
# Out:
#   YEAR_MONTH          DAY_TYPE  TIME_PER_HOUR PT_TYPE ORIGIN_PT_CODE  \
# 0    2026-05  WEEKENDS/HOLIDAY             19   TRAIN           EW28
# 1    2026-05           WEEKDAY              9   TRAIN            PW3
# 2    2026-05           WEEKDAY             20   TRAIN            PW4
# 3    2026-05  WEEKENDS/HOLIDAY             11   TRAIN           TE24
# 4    2026-05  WEEKENDS/HOLIDAY             16   TRAIN            TE4
#
#   DESTINATION_PT_CODE  TOTAL_TRIPS
# 0            CC17/TE9           16
# 1                 EW1            1
# 2                CC27            4
# 3           CC10/DT26            1
# 4                DT22            1

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Commerical Retail Rental Dataset

# %%
# check for missing values

rental_dataset.isnull().sum()
# Out:
# Postal District            0
# Floor Level                0
# Floor Area (SQM)           0
# 25th Percentile ($ PSM)    0
# Median ($PSM)              0
# 75th Percentile ($PSM)     0
# Reference Period           0
# dtype: int64

# %%
# remove missing values

rental_dataset.dropna()

rental_dataset.head()
# Out:
#    Postal District Floor Level Floor Area (SQM)  25th Percentile ($ PSM)  \
# 0                1  B1 & Below       30 & Below                    69.89
# 1                1  B1 & Below        >30 - 100                    65.45
# 2                1  B1 & Below       >100 - 300                    50.33
# 3                1     Level 1       30 & Below                    87.36
# 4                1     Level 1        >30 - 100                    75.26
#
#   Median ($PSM) 75th Percentile ($PSM) Reference Period
# 0         70.20                 112.70           2021Q1
# 1         87.61                  98.41           2021Q1
# 2         57.70                  87.20           2021Q1
# 3        123.94                 222.00           2021Q1
# 4        109.37                 147.04           2021Q1

# %% [markdown]
# ## Geo Dataset

# %% [markdown]
# ## NEA Licensed Eating Establishments Dataset

# %% [markdown]
# ## Population by Planning Area Subzone Dataset

# %% [markdown]
# ## MRT Traffic by station code dataset

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Commerical Retail Rental Dataset

# %% [markdown]
# ## Geo Dataset

# %% [markdown]
# ## NEA Licensed Eating Establishments Dataset

# %% [markdown]
# ## Population by Planning Area Subzone Dataset

# %% [markdown]
# ## MRT Traffic by station code dataset
